# %%
from pyspark.sql import SparkSession

# Create a Spark session
spark = SparkSession.builder \
    .appName("LocalSparkSession") \
    .master("local[*]") \
    .getOrCreate()

# Verify the session
print("Spark session created:", spark.version)
# Out:
# Spark session created: 3.5.3

# %%
flightData = spark\
  .read\
  .option("inferSchema", "true")\
  .option("header", "true")\
  .csv("../flight_data/Air Carrier Financial-B1/output/*.csv")

# %%
flightData.show()
# Out:
# +--------+--------------+----------------+----------------+-----------------+-----------------+------------------+-------------+---------------+-----------+-----------------+--------------+-------------+-----------------+------------+-----------------+-----------------+--------------+------+-----------------+------------+---------------+---------------+----------+-----------------+-----------------+-----------------+-----------------+-------------+--------------+------------+----------+-----------------+---------------+---------------+---------------+---------------+-----------------+-------------+-------------+-------------+----------+---------+----------------+-------------+----------------+--------------+--------------+------------+-----------------+----------------+------------+---------+---------------+---------------+-----------+---------+-------------+----------+--------------+-------------+---------------+---------------+------------+-------------+---------------+------------
# ...

# %%
from pymongo import MongoClient
import os
from dotenv import load_dotenv

load_dotenv()
username = os.getenv('MONGO_INITDB_ROOT_USERNAME')
password = os.getenv('MONGO_INITDB_ROOT_PASSWORD')

client = MongoClient(f"mongodb://{username}:{password}@localhost:27017/?authSource=admin")
db = client[os.getenv('MONGO_DB_NAME')]
try:
    # Send a ping command to the server
    server_info = client.server_info()  # Fetching server info as a test
    print("Successfully connected to MongoDB")
except:
    print("Could not connect to MongoDB")
# Out:
# Successfully connected to MongoDB

# %%
print(os.getenv('MONGO_DB_NAME'))
# Out:
# test-db

# %%
print(password)
# Out:
# asdf

# %%
collection = db["flight_econ"]
data_to_insert = [row.asDict() for row in flightData.collect()]
collection.insert_many(data_to_insert)
# Out:
# InsertManyResult([ObjectId('6754b01a71b000c9d00ba196'), ObjectId('6754b01a71b000c9d00ba197'), ObjectId('6754b01a71b000c9d00ba198'), ObjectId('6754b01a71b000c9d00ba199'), ObjectId('6754b01a71b000c9d00ba19a'), ObjectId('6754b01a71b000c9d00ba19b'), ObjectId('6754b01a71b000c9d00ba19c'), ObjectId('6754b01a71b000c9d00ba19d'), ObjectId('6754b01a71b000c9d00ba19e'), ObjectId('6754b01a71b000c9d00ba19f'), ObjectId('6754b01a71b000c9d00ba1a0'), ObjectId('6754b01a71b000c9d00ba1a1'), ObjectId('6754b01a71b000c9d00ba1a2'), ObjectId('6754b01a71b000c9d00ba1a3'), ObjectId('6754b01a71b000c9d00ba1a4'), ObjectId('6754b01a71b000c9d00ba1a5'), ObjectId('6754b01a71b000c9d00ba1a6'), ObjectId('6754b01a71b000c9d00ba1a7'), ObjectId('6754b01a71b000c9d00ba1a8'), ObjectId('6754b01a71b000c9d00ba1a9'), ObjectId('6754b01a71b000c9d00ba1aa'), ObjectId('6754b01a71b000c9d00ba1ab'), ObjectId('6754b01a71b000c9d00ba1ac'), ObjectId('6754b01a71b000c9d00ba1ad'), ObjectId('6754b01a71b000c9d00ba1ae'), ObjectId('6754b01a71b000c9d00b
# ...
